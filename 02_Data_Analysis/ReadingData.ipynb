# %% [markdown]
# # Reading Data From Different Sources

# %%
import pandas as pd
from io import StringIO as sio

Data = '{"Employee_name":"James","Email":"james@gmail.com","Job_Title":[{"Title1":"Data Analyst","Title2":"Senior Data Analyst"}],"Salary":50000}'

df = pd.read_json(sio(Data))
df
# Out:
#   Employee_name            Email  \
# 0         James  james@gmail.com
#
#                                            Job_Title  Salary
# 0  {'Title1': 'Data Analyst', 'Title2': 'Senior D...   50000

# %%
df.to_json()
# Out:
# '{"Employee_name":{"0":"James"},"Email":{"0":"james@gmail.com"},"Job_Title":{"0":{"Title1":"Data Analyst","Title2":"Senior Data Analyst"}},"Salary":{"0":50000}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"Employee_name":"James","Email":"james@gmail.com","Job_Title":{"Title1":"Data Analyst","Title2":"Senior Data Analyst"},"Salary":50000}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"Employee_name":"James","Email":"james@gmail.com","Job_Title":{"Title1":"Data Analyst","Title2":"Senior Data Analyst"},"Salary":50000}]'

# %%
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File C:\Program Files\Python312\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File C:\Program Files\Python312\Lib\http\client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\Program Files\Python312\Lib\http\client.py:1382, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1381     body = _encode(body, 'body')
# ...

# %%
#<script src="https://gist.github.com/tijptjik/9408623.js"></script>

# %%
# https://gist.githubusercontent.com/tijptjik/9408623/raw/b237fa5848349a14a14e5d4107dc7897c21951f5/wine.csv

# %%
df = pd.read_csv("https://gist.githubusercontent.com/tijptjik/9408623/raw/b237fa5848349a14a14e5d4107dc7897c21951f5/wine.csv")

# %%
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
df.to_csv("Wine_data.csv") # Saves the dataframe to a CSV file named 'Wine_data.csv' in the current working directory.

# %%
url="https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/"

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 1.4 MB/s eta 0:00:03
#    ------- -------------------------------- 0.8/4.0 MB 1.3 MB/s eta 0:00:03
#    ------- -------------------------------- 0.8/4.0 MB 1.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.0/4.0 MB 1.2 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 1.1 MB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 1.1 MB/s eta 0:00:03
#    --------------- ------------------------ 1.6/4.0 MB 998.3 kB/s eta 0:00:03
#    ------------------ --------------------- 1.8/4.0 MB 1.0 MB/s eta 0:00:03
#    ------------------ --------------------- 1.8/4.0 MB 1.0 MB/s eta 0:00:03
#    -------------------- ------------------- 2.1/4.0 MB 903.5 kB/s eta 0:00:03
# ...

# %%
# !pip install html5lib
# Out:
# ...
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# ...
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# ...
#
#    ---------------------------------------- 0/2 [webencodings]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    ---------------------------------------- 2/2 [html5lib]
#
# ...

# %%
# !pip install beautifulsoup4
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [soupsieve]
#    ------------- -------------------------- 1/3 [soupsieve]
#    -------------------------- ------------- 2/3 [beautifulsoup4]
#    -------------------------- ------------- 2/3 [beautifulsoup4]
#    -------------------------- ------------- 2/3 [beautifulsoup4]
#    ---------------------------------------- 3/3 [beautifulsoup4]
#
# ...

# %%
df = pd.read_html(url)

# %%
df
# Out:
# [                                            Bank Name                City  \
#  0                        The Santa Anna National Bank          Santa Anna
#  1                                Pulaski Savings Bank             Chicago
#  2                  The First National Bank of Lindsay             Lindsay
#  3               Republic First Bank dba Republic Bank        Philadelphia
#  4                                       Citizens Bank            Sac City
#  5                            Heartland Tri-State Bank             Elkhart
#  6                                 First Republic Bank       San Francisco
#  7                                      Signature Bank            New York
#  8                                 Silicon Valley Bank         Santa Clara
#  9                                   Almena State Bank              Almena
#  10                         First City Bank of Florida   Fort Walton Beach
# ...

# %%
df[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
url="https://en.wikipedia.org/wiki/Mobile_country_code"
df = pd.read_html(url,match="Country",header=0)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 url="https://en.wikipedia.org/wiki/Mobile_country_code"
# ----> 2 df = pd.read_html(url,match="Country",header=0)
#
# File d:\Data_Analyst_Bootcamp\.venv\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# ...

# %%
# !pip install openpyxl # For .xlsx files
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
df_excel = pd.read_excel("Excel_data.xlsx")

# %%
df_excel
# Out:
#      Name  Age
# 0  Pankaj   21
# 1    Yash   23
# 2  Nikhil   24
# 3  Chirag   25

# %%
df_excel.to_pickle("Pickle_data")

# %%
pd.read_pickle("Pickle_data")
# Out:
#      Name  Age
# 0  Pankaj   21
# 1    Yash   23
# 2  Nikhil   24
# 3  Chirag   25
